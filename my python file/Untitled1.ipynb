# %%
import pandas as pd
import numpy as np

df=pd.read_csv("flag.csv")
df
# Out:
#               Afghanistan  5  1    648   16  10  2  0   3  5.1  ...  0.5  0.6  \
# 0                 Albania  3  1     29    3   6  6  0   0    3  ...    0    0
# 1                 Algeria  4  1   2388   20   8  2  2   0    3  ...    0    0
# 2          American-Samoa  6  3      0    0   1  1  0   0    5  ...    0    0
# 3                 Andorra  3  1      0    0   6  0  3   0    3  ...    0    0
# 4                  Angola  4  2   1247    7  10  5  0   2    3  ...    0    0
# 5                Anguilla  1  4      0    0   1  1  0   1    3  ...    0    0
# 6         Antigua-Barbuda  1  4      0    0   1  1  0   1    5  ...    0    0
# 7               Argentina  2  3   2777   28   2  0  0   3    2  ...    0    0
# 8               Argentine  2  3   2777   28   2  0  0   3    3  ...    0    0
# 9               Australia  6  2   7690   15   1  1  0   0    3  ...    1    1
# 10                Austria  3  1     84    8   4  0  0   3    2  ...    0    0
# ...
