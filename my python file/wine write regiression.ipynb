# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import ensemble
from sklearn.metrics import median_absolute_error
from sklearn.externals import joblib
# Out:
# C:\Users\gowri\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
df=pd.read_csv("train_white.csv")
del df['Unnamed: 0']
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            5.6              0.32         0.33            7.40      0.037
# 1            5.8              0.15         0.49            1.10      0.048
# 2            6.6              0.22         0.35            1.40      0.050
# 3            7.5              0.29         0.31            8.95      0.055
# 4            6.4              0.20         0.22            7.40      0.032
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 25.0                  95.0  0.99268  3.25       0.49
# 1                 21.0                  98.0  0.99290  3.19       0.48
# 2                 23.0                  83.0  0.99019  3.17       0.48
# 3                 20.0                 151.0  0.99680  3.08       0.54
# 4                 53.0                 172.0  0.99404  3.24       0.58
#
#    alcohol  quality
# 0     11.1        6
# 1      9.2        5
# 2     12.0        7
# ...
